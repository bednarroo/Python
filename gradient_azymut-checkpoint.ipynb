# %%
# Program do liczenia azymtów oraz gradientów


import numpy as np


A = np.array([[1,0,0],[2,1.3,-1.7],[3,2.5,-1.5],[4,-5.25,-9],[5,-1.5,1.5],[6,0.15,1.25],[7,0,0],[8,2.2,-0.05],
[9,1.5,-2.7],[10,1.65,-1.25],[11,0.5,-2.25],[12,-0.4,-0.4],[13,0,0],[14,1.75,-0.5],[15,0.6,-2],[16,0.4,-1.4],
[17,0.5,-1.1],[18,1.2,0.5],[19,0,0],[20,1.25,-1.25],[21,1.4,-0.85],[22,1.5,-1.2],[23,4,-1.2],[24,3.8,-0.2],
[25,0,0],[26,0.2,-0.8],[27,-6.5,-1],[28,3.3,-1.3],[29,1.5,-3.7],[30,-1,0],[31,0,0],[32,4.8,-0.3],[33,11.75,5.7],
[34,1.9,-11.1],[35,-2,-1.9],[36,0,2.5]])

#obliczanie gradientów
import math as m
import numpy as np

len(A)
grad=[]
i=0
while i < len(A):
    grad=[i+1,m.sqrt(A[i,1]*A[i,1]+ A[i,2]*A[i,2])]
    i=i+1
    print(grad)
# Out:
# [1, 0.0]
# [2, 2.1400934559032696]
# [3, 2.9154759474226504]
# [4, 10.419332992087353]
# [5, 2.1213203435596424]
# [6, 1.2589678312014172]
# [7, 0.0]
# [8, 2.200568108466539]
# [9, 3.0886890422961004]
# [10, 2.0700241544484452]
# [11, 2.3048861143232218]
# [12, 0.5656854249492381]
# [13, 0.0]
# [14, 1.8200274723201295]
# [15, 2.08806130178211]
# [16, 1.4560219778561034]
# [17, 1.2083045973594573]
# [18, 1.3]
# [19, 0.0]
# [20, 1.7677669529663689]
# [21, 1.63783393541592]
# [22, 1.9209372712298547]
# [23, 4.17612260356422]
# [24, 3.8052595180880893]
# [25, 0.0]
# [26, 0.8246211251235323]
# [27, 6.576473218982953]
# [28, 3.5468295701936396]
# [29, 3.992492955535426]
# [30, 1.0]
# [31, 0.0]
# [32, 4.809365862564419]
# [33, 13.059575031370661]
# [34, 11.261438629233833]
# [35, 2.758622844826744]
# [36, 2.5]

# %%
#obliczanie azymutow
import math as m
import numpy as np
A = np.array([[1,0,0],[2,1.3,-1.7],[3,2.5,-1.5],[4,-5.25,-9],[5,-1.5,1.5],[6,0.15,1.25],[7,0,0],[8,2.2,-0.05],
[9,1.5,-2.7],[10,1.65,-1.25],[11,0.5,-2.25],[12,-0.4,-0.4],[13,0,0],[14,1.75,-0.5],[15,0.6,-2],[16,0.4,-1.4],
[17,0.5,-1.1],[18,1.2,0.5],[19,0,0],[20,1.25,-1.25],[21,1.4,-0.85],[22,1.5,-1.2],[23,4,-1.2],[24,3.8,-0.2],
[25,0,0],[26,0.2,-0.8],[27,-6.5,-1],[28,3.3,-1.3],[29,1.5,-3.7],[30,-1,0],[31,0,0],[32,4.8,-0.3],[33,11.75,5.7],
[34,1.9,-11.1],[35,-2,-1.9],[36,0,2.5]])

len(A)
print(m.pi)
azymut_g=[]
i=0
while i < len(A):
    if A[i,1] == 0 and A[i,2] == 0:
        azymut_g=[i+1,0]
    elif A[i,1] == 0 and A[i,2] > 0:
        azymut_g=[i+1,100] 
    elif A[i,1] == 0 and A[i,2] < 0:
        azymut_g=[i+1,300]
    elif A[i,1] > 0 and A[i,2] == 0:
        azymut_g=[i+1,0] 
    elif A[i,1] < 0 and A[i,2] == 0:
        azymut_g=[i+1,200]
    elif A[i,1] > 0 and A[i,2] > 0:
        azymut_g=[i+1,m.atan(A[i,2]/A[i,1])*(200/m.pi)]
    elif A[i,1] < 0 and A[i,2] > 0:
        azymut_g=[i+1,m.atan(A[i,2]/A[i,1])*(200/m.pi)+200]
    elif A[i,1] < 0 and A[i,2] < 0:
        azymut_g=[i+1,m.atan(A[i,2]/A[i,1])*(200/m.pi)+200]
    elif A[i,1] > 0 and A[i,2] < 0:
        azymut_g=[i+1,m.atan(A[i,2]/A[i,1])*(200/m.pi)+400]
    else:
        print("Cos poszlo nie tak")
    i=i+1
    print(azymut_g)
# Out:
# 3.141592653589793
# [1, 0]
# [2, 341.56150736823173]
# [3, 365.59582607547384]
# [4, 266.3817364849675]
# [5, 150.0]
# [6, 92.39691843041007]
# [7, 0]
# [8, 398.5533859193568]
# [9, 332.282893443419]
# [10, 358.7259036688647]
# [11, 313.9208974546128]
# [12, 250.0]
# [13, 0]
# [14, 382.282893443419]
# [15, 318.55471581554843]
# [16, 317.717106556581]
# [17, 327.15994975601836]
# [18, 25.133183275600476]
# [19, 0]
# [20, 350.0]
# [21, 365.26252033958065]
# [22, 357.04465749545545]
# [23, 381.4452841844515]
# [24, 396.65245832868516]
# [25, 0]
# [26, 315.59582607547384]
# [27, 209.71795806950578]
# [28, 376.10951741772453]
# [29, 324.519888402678]
# [30, 200]
# [31, 0]
# [32, 396.02629513889184]
# [33, 28.75368842583805]
# [34, 310.79250113882256]
# [35, 248.36799920623798]
# [36, 100]
